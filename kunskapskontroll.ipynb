# %% [markdown]
# # Del 1 – Teoretiska frågor och Python-övningar

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Del 2 – Dataanalys i Python

# %%
print("Diamonds!!")
# Out:
# Diamonds!!
